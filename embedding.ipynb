# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From d:\Generative AI\Project 2\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good'
    ]

# %%
## Define the vecabulary size
vec_size=10000

# %%
## One Hot Representation
one_hot_repr = [one_hot(words,vec_size) for words in sent]
one_hot_repr
# Out:
# [[4604, 134, 2290, 356],
#  [4604, 134, 2290, 1527],
#  [4604, 9266, 2290, 6635],
#  [9292, 1038, 1012, 8025, 3223],
#  [9292, 1038, 1012, 8025, 6517],
#  [6085, 4604, 2033, 2290, 6882],
#  [1758, 6304, 7125, 8025]]

# %%
## Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 4604  134 2290  356]
#  [   0    0    0    0 4604  134 2290 1527]
#  [   0    0    0    0 4604 9266 2290 6635]
#  [   0    0    0 9292 1038 1012 8025 3223]
#  [   0    0    0 9292 1038 1012 8025 6517]
#  [   0    0    0 6085 4604 2033 2290 6882]
#  [   0    0    0    0 1758 6304 7125 8025]]

# %%
## Feature Representation
dim=10
model = Sequential()
model.add(Embedding(vec_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From d:\Generative AI\Project 2\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Generative AI\Project 2\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.01959481, -0.04566355, -0.02953751,  0.02877957,
#          -0.00443441, -0.01889149, -0.01363713,  0.03819347,
#          -0.02011435, -0.02324287],
#         [ 0.02872255,  0.03104473, -0.00651038, -0.00196815,
#           0.02644452,  0.01968808, -0.0385897 , -0.02542507,
#           0.02016535, -0.04895535],
#         [ 0.03869921, -0.02696084,  0.0497557 ,  0.01838743,
#          -0.04953609,  0.00891825, -0.02603526,  0.03894259,
#          -0.01172484,  0.01634112],
#         [-0.02542729, -0.00215877, -0.04921751, -0.02024628,
#           0.0464203 , -0.03764708, -0.02392867, -0.02028728,
#          -0.01210667, -0.04948915]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.01959481, -0.04566355, -0.02953751,  0.02877957,
#          -0.00443441, -0.01889149, -0.01363713,  0.03819347,
#          -0.02011435, -0.02324287],
#         [ 0.02872255,  0.03104473, -0.00651038, -0.00196815,
#           0.02644452,  0.01968808, -0.0385897 , -0.02542507,
#           0.02016535, -0.04895535],
#         [ 0.03869921, -0.02696084,  0.0497557 ,  0.01838743,
#          -0.04953609,  0.00891825, -0.02603526,  0.03894259,
#          -0.01172484,  0.01634112],
#         [ 0.0431731 ,  0.02160076,  0.04174561,  0.02641961,
#          -0.01536313, -0.0125108 ,  0.03590378, -0.03979544,
#           0.03110241,  0.01053067]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.01959481, -0.04566355, -0.02953751,  0.02877957,
#          -0.00443441, -0.01889149, -0.01363713,  0.03819347,
#          -0.02011435, -0.02324287],
#         [-0.03291597,  0.02645464,  0.04930259,  0.02128191,
#          -0.00964028,  0.02788377, -0.02483441,  0.04725173,
#           0.02906528,  0.01660972],
#         [ 0.03869921, -0.02696084,  0.0497557 ,  0.01838743,
#          -0.04953609,  0.00891825, -0.02603526,  0.03894259,
#          -0.01172484,  0.01634112],
#         [ 0.01156628,  0.04717393, -0.03514712, -0.03578355,
#          -0.02708508,  0.01812884, -0.00560986,  0.02211205,
#           0.02804567, -0.0473424 ]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [-0.02380493, -0.02551224,  0.03047973, -0.00730341,
#           0.01512939,  0.02511081,  0.04122715, -0.03441559,
#          -0.03531381,  0.0142874 ],
#         [-0.01631503, -0.01585962,  0.01581689,  0.03258378,
#          -0.01285409,  0.00299107,  0.02265033, -0.00742084,
#          -0.04102789,  0.04069998],
#         [ 0.02254558,  0.00422534, -0.0380021 , -0.00411294,
#           0.0039819 ,  0.00800178,  0.04669955,  0.04523451,
#           0.02875682, -0.04360929],
#         [-0.04983732,  0.02715948,  0.02830298, -0.02280531,
#          -0.02259398, -0.01362855,  0.0127189 , -0.04751682,
#          -0.008134  ,  0.04028168],
#         [ 0.0218558 , -0.00132636,  0.0307107 ,  0.0026511 ,
#           0.04215821, -0.03342273,  0.04998784,  0.0445701 ,
#           0.0489488 ,  0.0184346 ]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [-0.02380493, -0.02551224,  0.03047973, -0.00730341,
#           0.01512939,  0.02511081,  0.04122715, -0.03441559,
#          -0.03531381,  0.0142874 ],
#         [-0.01631503, -0.01585962,  0.01581689,  0.03258378,
#          -0.01285409,  0.00299107,  0.02265033, -0.00742084,
#          -0.04102789,  0.04069998],
#         [ 0.02254558,  0.00422534, -0.0380021 , -0.00411294,
#           0.0039819 ,  0.00800178,  0.04669955,  0.04523451,
#           0.02875682, -0.04360929],
#         [-0.04983732,  0.02715948,  0.02830298, -0.02280531,
#          -0.02259398, -0.01362855,  0.0127189 , -0.04751682,
#          -0.008134  ,  0.04028168],
#         [ 0.00596301, -0.03778859,  0.02425544, -0.02634181,
#           0.00894067, -0.03155418, -0.02933062, -0.00579426,
#           0.01278288, -0.04870109]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [-0.02285881, -0.0285913 , -0.03580818,  0.02659244,
#          -0.03135175,  0.02409396,  0.04621352, -0.02998201,
#           0.00918827, -0.03964962],
#         [ 0.01959481, -0.04566355, -0.02953751,  0.02877957,
#          -0.00443441, -0.01889149, -0.01363713,  0.03819347,
#          -0.02011435, -0.02324287],
#         [-0.03455037, -0.01852446,  0.00553206, -0.00812368,
#           0.01861804, -0.00291408, -0.03837974,  0.03958633,
#          -0.02325626,  0.0066694 ],
#         [ 0.03869921, -0.02696084,  0.0497557 ,  0.01838743,
#          -0.04953609,  0.00891825, -0.02603526,  0.03894259,
#          -0.01172484,  0.01634112],
#         [ 0.02146265, -0.03018546,  0.03670505,  0.0364863 ,
#          -0.03626505, -0.00477114,  0.04668925, -0.00177713,
#          -0.03365768,  0.03737338]],
#
#        [[ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [ 0.00235089, -0.00681648, -0.04284845, -0.03729353,
#           0.0415836 ,  0.00391976, -0.02395814,  0.01499375,
#          -0.03072491, -0.00320804],
#         [-0.00715026, -0.02100245, -0.03313645,  0.01027142,
#           0.00314709, -0.02509784,  0.03646905,  0.04934475,
#           0.02482723,  0.02690107],
#         [ 0.01061708, -0.00328528, -0.00293661, -0.02523512,
#          -0.0398467 ,  0.04886326,  0.00554733,  0.03864393,
#          -0.00457077, -0.01292404],
#         [ 0.01256212, -0.00915533, -0.0429152 ,  0.04266855,
#           0.0081424 , -0.00210141, -0.00276647, -0.00828993,
#          -0.02576833, -0.03923493],
#         [-0.04983732,  0.02715948,  0.02830298, -0.02280531,
#          -0.02259398, -0.01362855,  0.0127189 , -0.04751682,
#          -0.008134  ,  0.04028168]]], dtype=float32)
